# %%
# 학습률 BERT, CRF 분리

import json
from pathlib import Path

import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer

# =========================
# 1. 파일 로드
# =========================
train_path = "klue_ner_train.json"
valid_path = "klue_ner_valid.json"

with open(train_path, "r", encoding="utf-8") as f:
    train_data = json.load(f)

with open(valid_path, "r", encoding="utf-8") as f:
    valid_data = json.load(f)

print("train size:", len(train_data))
print("valid size:", len(valid_data))
print(train_data[0].keys())
print(train_data[0])
# Out:
# train size: 21008
# valid size: 5000
# dict_keys(['id', 'sentence', 'tokens', 'tags', 'tag_ids'])
# {'id': 0, 'sentence': '특히 <영동고속도로:LC> <강릉:LC> 방향 <문막휴게소:LC>에서 <만종분기점:LC>까지 <5㎞:QT> 구간에는 승용차 전용 임시 갓길차로제를 운영하기로 했다.', 'tokens': ['특', '히', ' ', '영', '동', '고', '속', '도', '로', ' ', '강', '릉', ' ', '방', '향', ' ', '문', '막', '휴', '게', '소', '에', '서', ' ', '만', '종', '분', '기', '점', '까', '지', ' ', '5', '㎞', ' ', '구', '간', '에', '는', ' ', '승', '용', '차', ' ', '전', '용', ' ', '임', '시', ' ', '갓', '길', '차', '로', '제', '를', ' ', '운', '영', '하', '기', '로', ' ', '했', '다', '.'], 'tags': ['O', 'O', 'O', 'B-LC', 'I-LC', 'I-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'B-LC', 'I-LC', 'O', 'O', 'O', 'O', 'B-LC', 'I-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'O', 'O', 'B-LC', 'I-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tag_ids': [12, 12, 12, 2, 3, 3, 3, 3, 3, 12, 2, 3, 12, 12, 12, 12, 2, 3, 3, 3, 3, 12, 12, 12, 2, 3, 3, 3, 3, 12, 12, 12, 8, 9, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]}

# %%
label_names = [
    "B-DT", "I-DT",
    "B-LC", "I-LC",
    "B-OG", "I-OG",
    "B-PS", "I-PS",
    "B-QT", "I-QT",
    "B-TI", "I-TI",
    "O"
]

label2id = {label: i for i, label in enumerate(label_names)}
id2label = {i: label for i, label in enumerate(label_names)}

print(label2id)
# Out:
# {'B-DT': 0, 'I-DT': 1, 'B-LC': 2, 'I-LC': 3, 'B-OG': 4, 'I-OG': 5, 'B-PS': 6, 'I-PS': 7, 'B-QT': 8, 'I-QT': 9, 'B-TI': 10, 'I-TI': 11, 'O': 12}

# %%
from transformers import AutoTokenizer

model_name = "klue/bert-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
def tokenize_and_align_labels_from_json(example, max_length=128):
    """
    example:
    {
        "sentence": ...,
        "tokens": [...],
        "tags": [...],
        "tag_ids": [...]
    }
    """

    tokens = example["tokens"]
    tag_ids = example["tag_ids"]

    encoding = tokenizer(
        tokens,
        is_split_into_words=True,
        truncation=True,
        padding="max_length",
        max_length=max_length,
        return_attention_mask=True
    )

    word_ids = encoding.word_ids()
    aligned_labels = []

    prev_word_idx = None
    o_id = label2id["O"]

    for word_idx in word_ids:
        # [CLS], [SEP], [PAD]
        if word_idx is None:
            aligned_labels.append(o_id)

        # 어떤 원래 토큰의 첫 번째 subword
        elif word_idx != prev_word_idx:
            aligned_labels.append(tag_ids[word_idx])

        # 같은 원래 토큰의 뒤 subword
        else:
            curr_label_id = tag_ids[word_idx]
            curr_label_name = id2label[curr_label_id]

            if curr_label_name.startswith("B-"):
                inside_label = "I-" + curr_label_name[2:]
                aligned_labels.append(label2id.get(inside_label, curr_label_id))
            else:
                aligned_labels.append(curr_label_id)

        prev_word_idx = word_idx

    item = {
        "input_ids": torch.tensor(encoding["input_ids"], dtype=torch.long),
        "attention_mask": torch.tensor(encoding["attention_mask"], dtype=torch.long),
        "labels": torch.tensor(aligned_labels, dtype=torch.long),
    }

    return item

# %%
class JsonNERDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        example = self.data[idx]
        return tokenize_and_align_labels_from_json(example, max_length=self.max_length)

# %%
max_length = 128
batch_size = 16

train_dataset = JsonNERDataset(train_data, tokenizer, max_length=max_length)
valid_dataset = JsonNERDataset(valid_data, tokenizer, max_length=max_length)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

batch = next(iter(train_loader))
print(batch["input_ids"].shape)      # [batch, seq_len]
print(batch["attention_mask"].shape) # [batch, seq_len]
print(batch["labels"].shape)         # [batch, seq_len]
# Out:
# torch.Size([16, 128])
# torch.Size([16, 128])
# torch.Size([16, 128])

# %%
sample = train_dataset[0]

tokens = tokenizer.convert_ids_to_tokens(sample["input_ids"].tolist())
labels = sample["labels"].tolist()
mask = sample["attention_mask"].tolist()

for i, (tok, lab, m) in enumerate(zip(tokens, labels, mask)):
    print(f"{i:3d} | {tok:12} | mask={m} | {lab:2d} | {id2label[lab]}")
# Out:
#   0 | [CLS]        | mask=1 | 12 | O
#   1 | 특            | mask=1 | 12 | O
#   2 | 히            | mask=1 | 12 | O
#   3 | 영            | mask=1 |  2 | B-LC
#   4 | 동            | mask=1 |  3 | I-LC
#   5 | 고            | mask=1 |  3 | I-LC
#   6 | 속            | mask=1 |  3 | I-LC
#   7 | 도            | mask=1 |  3 | I-LC
#   8 | 로            | mask=1 |  3 | I-LC
#   9 | 강            | mask=1 |  2 | B-LC
#  10 | 릉            | mask=1 |  3 | I-LC
#  11 | 방            | mask=1 | 12 | O
#  12 | 향            | mask=1 | 12 | O
#  13 | 문            | mask=1 |  2 | B-LC
#  14 | 막            | mask=1 |  3 | I-LC
#  15 | 휴            | mask=1 |  3 | I-LC
#  16 | 게            | mask=1 |  3 | I-LC
#  17 | 소            | mask=1 |  3 | I-LC
#  18 | 에            | mask=1 | 12 | O
#  19 | 서            | mask=1 | 12 | O
#  20 | 만            | mask=1 |  2 | B-LC
#  21 | 종            | mask=1 |  3 | I-LC
#  22 | 분            | mask=1 |  3 | I-LC
#  23 | 기            | mask=1 |  3 | I-LC
#  24 | 점            | mask=1 |  3 | I-LC
#  25 | 까            | mask=1 | 12 | O
#  26 | 지            | mask=1 | 12 | O
#  27 | 5            | mask=1 |  8 | B-QT
#  28 | ㎞            | mask=1 |  9 | I-QT
#  29 | 구            | mask=1 | 12 | O
#  30 | 간            | mask=1 | 12 | O
#  31 | 에            | mask=1 | 12 | O
#  32 | 는            | mask=1 | 12 | O
#  33 | 승            | mask=1 | 12 | O
#  34 | 용            | mask=1 | 12 | O
#  35 | 차            | mask=1 | 12 | O
#  36 | 전            | mask=1 | 12 | O
#  37 | 용            | mask=1 | 12 | O
#  38 | 임            | mask=1 | 12 | O
#  39 | 시            | mask=1 | 12 | O
#  40 | 갓            | mask=1 | 12 | O
#  41 | 길            | mask=1 | 12 | O
#  42 | 차            | mask=1 | 12 | O
#  43 | 로            | mask=1 | 12 | O
#  44 | 제            | mask=1 | 12 | O
#  45 | 를            | mask=1 | 12 | O
#  46 | 운            | mask=1 | 12 | O
#  47 | 영            | mask=1 | 12 | O
#  48 | 하            | mask=1 | 12 | O
#  49 | 기            | mask=1 | 12 | O
#  50 | 로            | mask=1 | 12 | O
#  51 | 했            | mask=1 | 12 | O
#  52 | 다            | mask=1 | 12 | O
#  53 | .            | mask=1 | 12 | O
#  54 | [SEP]        | mask=1 | 12 | O
#  55 | [PAD]        | mask=0 | 12 | O
#  56 | [PAD]        | mask=0 | 12 | O
#  57 | [PAD]        | mask=0 | 12 | O
#  58 | [PAD]        | mask=0 | 12 | O
#  59 | [PAD]        | mask=0 | 12 | O
#  60 | [PAD]        | mask=0 | 12 | O
#  61 | [PAD]        | mask=0 | 12 | O
#  62 | [PAD]        | mask=0 | 12 | O
#  63 | [PAD]        | mask=0 | 12 | O
#  64 | [PAD]        | mask=0 | 12 | O
#  65 | [PAD]        | mask=0 | 12 | O
#  66 | [PAD]        | mask=0 | 12 | O
#  67 | [PAD]        | mask=0 | 12 | O
#  68 | [PAD]        | mask=0 | 12 | O
#  69 | [PAD]        | mask=0 | 12 | O
#  70 | [PAD]        | mask=0 | 12 | O
#  71 | [PAD]        | mask=0 | 12 | O
#  72 | [PAD]        | mask=0 | 12 | O
#  73 | [PAD]        | mask=0 | 12 | O
#  74 | [PAD]        | mask=0 | 12 | O
#  75 | [PAD]        | mask=0 | 12 | O
#  76 | [PAD]        | mask=0 | 12 | O
#  77 | [PAD]        | mask=0 | 12 | O
#  78 | [PAD]        | mask=0 | 12 | O
#  79 | [PAD]        | mask=0 | 12 | O
#  80 | [PAD]        | mask=0 | 12 | O
#  81 | [PAD]        | mask=0 | 12 | O
#  82 | [PAD]        | mask=0 | 12 | O
#  83 | [PAD]        | mask=0 | 12 | O
#  84 | [PAD]        | mask=0 | 12 | O
#  85 | [PAD]        | mask=0 | 12 | O
#  86 | [PAD]        | mask=0 | 12 | O
#  87 | [PAD]        | mask=0 | 12 | O
#  88 | [PAD]        | mask=0 | 12 | O
#  89 | [PAD]        | mask=0 | 12 | O
#  90 | [PAD]        | mask=0 | 12 | O
#  91 | [PAD]        | mask=0 | 12 | O
#  92 | [PAD]        | mask=0 | 12 | O
#  93 | [PAD]        | mask=0 | 12 | O
#  94 | [PAD]        | mask=0 | 12 | O
#  95 | [PAD]        | mask=0 | 12 | O
#  96 | [PAD]        | mask=0 | 12 | O
#  97 | [PAD]        | mask=0 | 12 | O
#  98 | [PAD]        | mask=0 | 12 | O
#  99 | [PAD]        | mask=0 | 12 | O
# 100 | [PAD]        | mask=0 | 12 | O
# 101 | [PAD]        | mask=0 | 12 | O
# 102 | [PAD]        | mask=0 | 12 | O
# 103 | [PAD]        | mask=0 | 12 | O
# 104 | [PAD]        | mask=0 | 12 | O
# 105 | [PAD]        | mask=0 | 12 | O
# 106 | [PAD]        | mask=0 | 12 | O
# 107 | [PAD]        | mask=0 | 12 | O
# 108 | [PAD]        | mask=0 | 12 | O
# 109 | [PAD]        | mask=0 | 12 | O
# 110 | [PAD]        | mask=0 | 12 | O
# 111 | [PAD]        | mask=0 | 12 | O
# 112 | [PAD]        | mask=0 | 12 | O
# 113 | [PAD]        | mask=0 | 12 | O
# 114 | [PAD]        | mask=0 | 12 | O
# 115 | [PAD]        | mask=0 | 12 | O
# 116 | [PAD]        | mask=0 | 12 | O
# 117 | [PAD]        | mask=0 | 12 | O
# 118 | [PAD]        | mask=0 | 12 | O
# 119 | [PAD]        | mask=0 | 12 | O
# 120 | [PAD]        | mask=0 | 12 | O
# 121 | [PAD]        | mask=0 | 12 | O
# 122 | [PAD]        | mask=0 | 12 | O
# 123 | [PAD]        | mask=0 | 12 | O
# 124 | [PAD]        | mask=0 | 12 | O
# 125 | [PAD]        | mask=0 | 12 | O
# 126 | [PAD]        | mask=0 | 12 | O
# 127 | [PAD]        | mask=0 | 12 | O

# %%
# !pip install pytorch-crf
# Out:
# Collecting pytorch-crf
#   Downloading pytorch_crf-0.7.2-py3-none-any.whl.metadata (2.4 kB)
# Downloading pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2

# %%
import torch
import torch.nn as nn
from transformers import BertModel
from torchcrf import CRF

class BertCRF(nn.Module):
    def __init__(self, model_name, num_classes, dropout=0.3):
        super(BertCRF, self).__init__()

        self.bert = BertModel.from_pretrained(model_name)
        hidden_size = self.bert.config.hidden_size

        self.dropout = nn.Dropout(dropout)
        self.position_wise_ff = nn.Linear(hidden_size, num_classes)
        self.crf = CRF(num_tags=num_classes, batch_first=True)

    def forward(self, input_ids, attention_mask=None, tags=None):
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        sequence_output = self.dropout(outputs.last_hidden_state)
        emissions = self.position_wise_ff(sequence_output)

        if attention_mask is not None:
            crf_mask = attention_mask.bool()
        else:
            crf_mask = torch.ones_like(input_ids, dtype=torch.bool)

        if tags is not None:
            # 학습할 때
            log_likelihood = self.crf(
                emissions,
                tags,
                mask=crf_mask,
                reduction='token_mean'
            )
            loss = -log_likelihood
            predictions = self.crf.decode(emissions, mask=crf_mask)
            return loss, predictions

        else:
            # 추론할 때
            predictions = self.crf.decode(emissions, mask=crf_mask)
            return predictions

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from seqeval) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.12/dist-packages (from seqeval) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=e585942a66c7aeda6c0ddcc67d44a148e46b5b0f5e999e1e8823b6a212bc72ae
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
import torch
from torch.optim import AdamW
from tqdm import tqdm
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report

def convert_predictions_to_labels(predictions, labels, attention_mask, input_ids, tokenizer, id2label):
    true_label_list = []
    pred_label_list = []

    if torch.is_tensor(labels):
        labels = labels.cpu().tolist()
    if torch.is_tensor(attention_mask):
        attention_mask = attention_mask.cpu().tolist()
    if torch.is_tensor(input_ids):
        input_ids = input_ids.cpu().tolist()

    for pred_seq, true_seq, mask_seq, input_id_seq in zip(predictions, labels, attention_mask, input_ids):
        true_labels = []
        pred_labels = []

        valid_len = sum(mask_seq)  # CRF decode 길이와 동일
        tokens = tokenizer.convert_ids_to_tokens(input_id_seq[:valid_len])

        for j in range(valid_len):
            tok = tokens[j]

            # special token 제외
            if tok in tokenizer.all_special_tokens:
                continue

            true_labels.append(id2label[true_seq[j]])
            pred_labels.append(id2label[pred_seq[j]])

        true_label_list.append(true_labels)
        pred_label_list.append(pred_labels)

    return true_label_list, pred_label_list

# %%
def token_level_accuracy(predictions, labels, attention_mask, input_ids, tokenizer):
    correct = 0
    total = 0

    if torch.is_tensor(labels):
        labels = labels.cpu().tolist()
    if torch.is_tensor(attention_mask):
        attention_mask = attention_mask.cpu().tolist()
    if torch.is_tensor(input_ids):
        input_ids = input_ids.cpu().tolist()

    for pred_seq, true_seq, mask_seq, input_id_seq in zip(predictions, labels, attention_mask, input_ids):
        valid_len = sum(mask_seq)
        tokens = tokenizer.convert_ids_to_tokens(input_id_seq[:valid_len])

        for j in range(valid_len):
            tok = tokens[j]

            # [CLS], [SEP] 제외
            if tok in tokenizer.all_special_tokens:
                continue

            if pred_seq[j] == true_seq[j]:
                correct += 1
            total += 1

    return correct / total if total > 0 else 0.0

# %%
from tqdm import tqdm

def train_one_epoch(model, dataloader, optimizer, device):
    model.train()
    total_loss = 0

    progress_bar = tqdm(dataloader, desc="Train", leave=False)

    for batch in progress_bar:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        loss, _ = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            tags=labels
        )
        weight = torch.where(labels > 0, 2.0, 0.1).to(device)

        # 문장 내 실제 유효한 토큰들에 대한 평균 가중치를 계산하여 적용
        active_weight = (weight * attention_mask).sum() / attention_mask.sum()
        weighted_loss = loss * active_weight

        weighted_loss.backward()
        optimizer.step()

        total_loss += loss.item()
        progress_bar.set_postfix(batch_loss=f"{loss.item():.4f}")

    avg_loss = total_loss / len(dataloader)
    return avg_loss

# %%
from seqeval.metrics import precision_score, recall_score, f1_score

def evaluate(model, dataloader, device, id2label, tokenizer):
    model.eval()

    total_loss = 0
    all_true_labels = []
    all_pred_labels = []
    total_correct = 0
    total_count = 0

    progress_bar = tqdm(dataloader, desc="Eval", leave=False)

    with torch.no_grad():
        for batch in progress_bar:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            loss, predictions = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                tags=labels
            )

            total_loss += loss.item()

            labels_cpu = labels.cpu().tolist()
            mask_cpu = attention_mask.cpu().tolist()
            input_ids_cpu = input_ids.cpu().tolist()

            for pred_seq, true_seq, mask_seq, input_id_seq in zip(
                predictions, labels_cpu, mask_cpu, input_ids_cpu
            ):
                valid_len = sum(mask_seq)
                tokens = tokenizer.convert_ids_to_tokens(input_id_seq[:valid_len])

                sent_true = []
                sent_pred = []

                for j in range(valid_len):
                    tok = tokens[j]

                    # [CLS], [SEP] 제외
                    if tok in tokenizer.all_special_tokens:
                        continue

                    true_id = true_seq[j]
                    pred_id = pred_seq[j]

                    sent_true.append(id2label[true_id])
                    sent_pred.append(id2label[pred_id])

                    if true_id == pred_id:
                        total_correct += 1
                    total_count += 1

                all_true_labels.append(sent_true)
                all_pred_labels.append(sent_pred)

    avg_loss = total_loss / len(dataloader)
    accuracy = total_correct / total_count if total_count > 0 else 0.0
    precision = precision_score(all_true_labels, all_pred_labels)
    recall = recall_score(all_true_labels, all_pred_labels)
    f1 = f1_score(all_true_labels, all_pred_labels)

    return avg_loss, accuracy, precision, recall, f1, all_true_labels, all_pred_labels

# %%
def train_model(model, train_loader, valid_loader, optimizer, device, id2label, tokenizer, epochs=5):
    best_f1 = 0.0

    for epoch in range(epochs):
        print(f"\n===== Epoch {epoch+1}/{epochs} =====")

        train_loss = train_one_epoch(model, train_loader, optimizer, device)

        val_loss, val_acc, val_precision, val_recall, val_f1, _, _ = evaluate(
            model, valid_loader, device, id2label, tokenizer
        )

        print(f"Train Loss     : {train_loss:.4f}")
        print(f"Valid Loss     : {val_loss:.4f}")
        print(f"Valid Accuracy : {val_acc:.4f}")
        print(f"Valid Precision: {val_precision:.4f}")
        print(f"Valid Recall   : {val_recall:.4f}")
        print(f"Valid F1       : {val_f1:.4f}")

        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save(model.state_dict(), "best_bert_crf.pt")
            print("Best model saved.")

    print(f"\nBest Valid F1: {best_f1:.4f}")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = BertCRF(
    model_name=model_name,
    num_classes=len(label_names),
    dropout=0.3
).to(device)

optimizer = AdamW([
    {"params": model.bert.parameters(), "lr": 2e-5},
    {"params": model.position_wise_ff.parameters(), "lr": 1e-4},
    {"params": model.crf.parameters(), "lr": 5e-4}
], weight_decay=0.01)

train_model(
    model=model,
    train_loader=train_loader,
    valid_loader=valid_loader,
    optimizer=optimizer,
    device=device,
    id2label=id2label,
    tokenizer=tokenizer,
    epochs=10
)
# Out:
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: klue/bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# bert.embeddings.position_ids               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ===== Epoch 1/10 =====
# Train Loss     : 0.2068
# Valid Loss     : 0.1307
# Valid Accuracy : 0.9463
# Valid Precision: 0.7877
# Valid Recall   : 0.7560
# Valid F1       : 0.7715
# Best model saved.
#
# ===== Epoch 2/10 =====
# Train Loss     : 0.0859
# Valid Loss     : 0.1013
# Valid Accuracy : 0.9524
# Valid Precision: 0.8218
# Valid Recall   : 0.7789
# Valid F1       : 0.7998
# Best model saved.
#
# ===== Epoch 3/10 =====
# Train Loss     : 0.0529
# Valid Loss     : 0.0900
# Valid Accuracy : 0.9553
# Valid Precision: 0.8150
# Valid Recall   : 0.8128
# Valid F1       : 0.8139
# Best model saved.
#
# ===== Epoch 4/10 =====
# Train Loss     : 0.0356
# Valid Loss     : 0.0875
# Valid Accuracy : 0.9549
# Valid Precision: 0.8196
# Valid Recall   : 0.8137
# Valid F1       : 0.8166
# Best model saved.
#
# ===== Epoch 5/10 =====
# Train Loss     : 0.0243
# Valid Loss     : 0.0923
# Valid Accuracy : 0.9573
# Valid Precision: 0.8276
# Valid Recall   : 0.8216
# Valid F1       : 0.8246
# Best model saved.
#
# ===== Epoch 6/10 =====
# Train Loss     : 0.0188
# Valid Loss     : 0.0882
# Valid Accuracy : 0.9563
# Valid Precision: 0.8201
# Valid Recall   : 0.8147
# Valid F1       : 0.8174
#
# ===== Epoch 7/10 =====
# Train Loss     : 0.0144
# Valid Loss     : 0.0934
# Valid Accuracy : 0.9581
# Valid Precision: 0.8262
# Valid Recall   : 0.8280
# Valid F1       : 0.8271
# Best model saved.
#
# ===== Epoch 8/10 =====
# Train Loss     : 0.0112
# Valid Loss     : 0.0962
# Valid Accuracy : 0.9566
# Valid Precision: 0.8170
# Valid Recall   : 0.8192
# Valid F1       : 0.8181
#
# ===== Epoch 9/10 =====
# Train Loss     : 0.0094
# Valid Loss     : 0.0973
# Valid Accuracy : 0.9582
# Valid Precision: 0.8239
# Valid Recall   : 0.8313
# Valid F1       : 0.8276
# Best model saved.
#
# ===== Epoch 10/10 =====
# Train Loss     : 0.0078
# Valid Loss     : 0.1009
# Valid Accuracy : 0.9575
# Valid Precision: 0.8305
# Valid Recall   : 0.8161
# Valid F1       : 0.8232
#
# Best Valid F1: 0.8276

# %%
import json
from tqdm import tqdm

def get_true_pred_sequences(model, dataloader, device, id2label, tokenizer):
    model.eval()

    all_true = []
    all_pred = []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Extract Predictions"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            predictions = model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )

            input_ids_cpu = input_ids.cpu().tolist()
            labels_cpu = labels.cpu().tolist()
            mask_cpu = attention_mask.cpu().tolist()

            for pred_seq, true_seq, input_id_seq, mask_seq in zip(
                predictions, labels_cpu, input_ids_cpu, mask_cpu
            ):
                valid_len = sum(mask_seq)
                tokens = tokenizer.convert_ids_to_tokens(input_id_seq[:valid_len])

                sent_true = []
                sent_pred = []

                for j in range(valid_len):
                    tok = tokens[j]

                    # special token 제외
                    if tok in tokenizer.all_special_tokens:
                        continue

                    sent_true.append(id2label[true_seq[j]])
                    sent_pred.append(id2label[pred_seq[j]])

                all_true.append(sent_true)
                all_pred.append(sent_pred)

    return all_true, all_pred

# %%
y_true, y_pred = get_true_pred_sequences(
    model=model,
    dataloader=valid_loader,
    device=device,
    id2label=id2label,
    tokenizer=tokenizer
)

print(y_true[:2])
print(y_pred[:2])
# Out:
# Extract Predictions: 100%|██████████| 313/313 [00:22<00:00, 14.13it/s]
# [['B-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]
# [['B-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]

# %%
assert len(y_true) == len(y_pred)

for t, p in zip(y_true, y_pred):
    assert len(t) == len(p)

print("문장 수:", len(y_true))
print("첫 문장 길이:", len(y_true[0]), len(y_pred[0]))
print("길이 검증 완료")
# Out:
# 문장 수: 5000
# 첫 문장 길이: 54 54
# 길이 검증 완료

# %%
with open("y_true.json", "w", encoding="utf-8") as f:
    json.dump(y_true, f, ensure_ascii=False, indent=2)

with open("y_pred.json", "w", encoding="utf-8") as f:
    json.dump(y_pred, f, ensure_ascii=False, indent=2)

print("저장 완료: y_true.json, y_pred.json")
# Out:
# 저장 완료: y_true.json, y_pred.json

# %%
# 상위 5개 오분류 문장만 출력해보기
error_count = 0
for i in range(len(y_true)):
    if y_true[i] != y_pred[i]:
        print(f"\n[Error Case {error_count + 1}] Index: {i}")
        print(f"정답(True): {y_true[i]}")
        print(f"예측(Pred): {y_pred[i]}")

        # 구체적으로 어디가 틀렸는지 비교
        diff = [f"{t}->{p}" for t, p in zip(y_true[i], y_pred[i]) if t != p]
        print(f"틀린 부분: {diff}")

        error_count += 1
        if error_count >= 5:
          break
# Out:
# [Error Case 1] Index: 3
# 정답(True): ['O', 'O', 'O', 'O', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'B-LC', 'I-LC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'O', 'O', 'O', 'B-DT', 'I-DT', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 예측(Pred): ['O', 'O', 'O', 'O', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'B-LC', 'I-LC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LC', 'I-LC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'O', 'O', 'O', 'B-DT', 'I-DT', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 틀린 부분: ['O->B-LC', 'O->I-LC', 'B-DT->O', 'I-DT->O', 'I-DT->B-DT']
#
# [Error Case 2] Index: 5
# 정답(True): ['B-QT', 'I-QT', 'I-QT', 'I-QT', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'I-PS', 'I-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'I-PS', 'I-PS', 'O', 'O', 'O', 'O', 'O', 'B-OG', 'I-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 예측(Pred): ['B-QT', 'I-QT', 'I-QT', 'I-QT', 'O', 'O', 'B-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'I-PS', 'I-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'B-OG', 'I-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 틀린 부분: ['B-QT->O', 'I-QT->B-QT', 'B-PS->O', 'I-PS->B-QT', 'I-PS->I-QT']
#
# [Error Case 3] Index: 7
# 정답(True): ['O', 'O', 'B-LC', 'I-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 예측(Pred): ['O', 'O', 'B-OG', 'I-OG', 'I-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 틀린 부분: ['B-LC->B-OG', 'I-LC->I-OG', 'I-LC->I-OG', 'I-LC->I-OG', 'I-LC->I-OG']
#
# [Error Case 4] Index: 10
# 정답(True): ['B-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 예측(Pred): ['B-PS', 'I-PS', 'I-PS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 틀린 부분: ['B-OG->B-PS', 'I-OG->I-PS', 'I-OG->I-PS']
#
# [Error Case 5] Index: 15
# 정답(True): ['B-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'O', 'B-OG', 'I-OG', 'I-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 예측(Pred): ['B-LC', 'I-LC', 'I-LC', 'I-LC', 'O', 'O', 'B-OG', 'I-OG', 'I-OG', 'I-OG', 'I-OG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PS', 'O', 'O', 'O', 'O', 'B-DT', 'I-DT', 'I-DT', 'I-DT', 'I-DT', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QT', 'I-QT', 'I-QT', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 틀린 부분: ['B-DT->O', 'I-DT->O', 'I-DT->B-DT']

# %%
from seqeval.metrics import classification_report

# 전체 검증 데이터에 대한 유형별 상세 리포트 출력
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           DT       0.84      0.86      0.85      2312
#           LC       0.68      0.70      0.69      1646
#           OG       0.75      0.74      0.75      2181
#           PS       0.88      0.79      0.83      4414
#           QT       0.89      0.92      0.90      3151
#           TI       0.90      0.92      0.91       545
#
#    micro avg       0.83      0.82      0.82     14249
#    macro avg       0.82      0.82      0.82     14249
# weighted avg       0.83      0.82      0.82     14249

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 2차원 리스트를 1차원으로 펼치기
flat_true = [tag for sent in y_true for tag in sent]
flat_pred = [tag for sent in y_pred for tag in sent]

# 태그 목록 추출
labels = sorted(list(set(flat_true)))

# 혼동 행렬 생성
cm = confusion_matrix(flat_true, flat_pred, labels=labels)
df_cm = pd.DataFrame(cm, index=labels, columns=labels)

plt.figure(figsize=(10, 8))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues')
plt.title('NER Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
